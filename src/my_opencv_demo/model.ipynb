# %%
import pandas as pd
import openpyxl
from geometry_msgs.msg import Point, Quaternion

# %%
df = pd.DataFrame([[11, 21, 31], [12, 22, 32], [31, 32, 33]],
                  index=['one', 'two', 'three'], columns=['a', 'b', 'c'])

# %%
s_pose = [0.01, 0.01, 0.01, 0.01, 0.01, 0.01]
i_pose = [0.02, 0.02, 0.02, 0.02, 0.02, 0.02]
f_pose = [0.03, 0.03, 0.03, 0.03, 0.03, 0.03]
e_pose = [0.04, 0.04, 0.04, 0.04, 0.04, 0.04]
obj = "red"

print(s_pose + i_pose)


dict = {
    "red_source": [
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "green_source": [
        0.4104479855298996,
        0.11042735528945924,
        0.7102134227752686,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "blue_source": [
        0.47651597917079913,
        -0.21451855647563933,
        0.7102106213569641,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "yellow_source": [
        0.4279762363433838,
        -0.09991081255674361,
        0.7102116346359253,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "red_initial": [
        0.5992134284600614,
        0.22233762395381926,
        0.7102144956588745,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "blue_initial": [
        0.5911234977096318,
        -0.2253051643371582,
        0.7102106213569641,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "green_initial": [
        0.601910072043538,
        0.09964079213142393,
        0.7102134823799133,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "yellow_initial": [
        0.601910072043538,
        -0.10260744589567186,
        0.7102116942405701,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "red_final": [
        0.41449342727661126,
        0.266831463098526,
        0.7102165222167969,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "blue_final": [
        0.4751679754257201,
        -0.2239563261270523,
        0.7102123498916626,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "green_final": [
        0.4091001307964323,
        0.11716871511936189,
        0.7102152705192566,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "yellow_final": [
        0.4239316886663436,
        -0.10260720002651214,
        0.7102134227752686,
        0.4198862767219542,
        0.2614387775659561,
        0.7102147340774536,
    ],
    "red_error": [
        0.004044547677040156,
        0.36452346056077545,
        1.7881393432617188e-06,
        0.0,
        1.5560312787897052e-14,
        0.36452346056077545,
    ],
    "blue_error": [
        0.004044547677040156,
        0.36452346056077545,
        1.7881393432617188e-06,
        0.0,
        1.5560312787897052e-14,
        0.36452346056077545,
    ],
    "green_error": [
        0.004044547677040156,
        0.36452346056077545,
        1.7881393432617188e-06,
        0.0,
        1.5560312787897052e-14,
        0.36452346056077545,
    ],
    "yellow_error": [
        0.004044547677040156,
        0.36452346056077545,
        1.7881393432617188e-06,
        0.0,
        1.5560312787897052e-14,
        0.36452346056077545,
    ],
}
# Out:
# [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02]

# %%
def get_dataframe(dict):
    result = pd.DataFrame()
    for object in ['red', 'blue', 'green', 'yellow']:

        s_pose = dict.get(f'{object}_source')
        i_pose = dict.get(f'{object}_initial')
        f_pose = dict.get(f'{object}_final')
        e_pose = dict.get(f'{object}_error')

        df = pd.DataFrame(
            [s_pose, i_pose, f_pose, e_pose],
            index=[f"Source {object}", f"Initial {object}", f"Final {object}", f"Error {object}"],
            columns=["x (mm)", "y (mm)", "z (mm)", "r (deg)", "p (deg)", "y (deg)"],
        )
        
        result = pd.concat([result, df], ignore_index=False)
            
    return result


df = get_dataframe(dict)
print(df)
# Out:
#                   x (mm)    y (mm)    z (mm)   r (deg)       p (deg)   y (deg)
# Source red      0.419886  0.261439  0.710215  0.419886  2.614388e-01  0.710215
# Initial red     0.599213  0.222338  0.710214  0.419886  2.614388e-01  0.710215
# Final red       0.414493  0.266831  0.710217  0.419886  2.614388e-01  0.710215
# Error red       0.004045  0.364523  0.000002  0.000000  1.556031e-14  0.364523
# Source blue     0.476516 -0.214519  0.710211  0.419886  2.614388e-01  0.710215
# Initial blue    0.591123 -0.225305  0.710211  0.419886  2.614388e-01  0.710215
# Final blue      0.475168 -0.223956  0.710212  0.419886  2.614388e-01  0.710215
# Error blue      0.004045  0.364523  0.000002  0.000000  1.556031e-14  0.364523
# Source green    0.410448  0.110427  0.710213  0.419886  2.614388e-01  0.710215
# Initial green   0.601910  0.099641  0.710213  0.419886  2.614388e-01  0.710215
# Final green     0.409100  0.117169  0.710215  0.419886  2.614388e-01  0.710215
# ...

# %%
folder = 'evaluation'
path = f'{folder}/pandas_to_excel.xlsx'

with pd.ExcelWriter(path) as writer:
    writer = openpyxl.load_workbook(path)
    sheet_obj = writer.active
    red_df.to_excel(writer, sheet_name='new_sheet1')

# %%
import math


x = [2]
x1 = [2]

print(math.dist(x, x1))
# Out:
# 0.0
